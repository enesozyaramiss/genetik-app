# %%
import pandas as pd
from clinvar_parser import enrich_clinvar_df

clinvar_df = pd.read_parquet("sampled_100.parquet")
clinvar_df = enrich_clinvar_df(clinvar_df)

# %%
clinvar_df
# Out:
#       CHROM        POS       ID REF ALT QUAL FILTER  \
# 0         7  146774401  1555617   T   G    .      .
# 1        17   11727893  1455280   G   A    .      .
# 2        15   77018465   451711   C   T    .      .
# 3         X   17376123  2903273   G   A    .      .
# 4        15  100054211  1297461   A   G    .      .
# ...     ...        ...      ...  ..  ..  ...    ...
# 99995     5   62357705  3251921   G   T    .      .
# 99996     3   53186256   474764   G   A    .      .
# 99997    10   67885011  1559401   C   A    .      .
# 99998     1   26729868  3693128   A   T    .      .
# 99999     1  208043175  3353562   A   G    .      .
#
#                                                     INFO      GENE  \
# 0      ALLELEID=1550322;CLNDISDB=MONDO:MONDO:0012400,...   CNTNAP2
# 1      AF_ESP=0.00023;AF_TGP=0.00060;ALLELEID=1464401...     DNAH9
# 2      AF_EXAC=0.00003;ALLELEID=445430;CLNDISDB=MedGe...   PSTPIP1
# 3      AF_EXAC=0.00010;ALLELEID=3068766;CLNDISDB=MOND...       NHS
# 4      AF_TGP=0.37260;ALLELEID=1287250;CLNDISDB=MedGe...  ADAMTS17
# ...                                                  ...       ...
# 99995  AF_EXAC=0.00001;ALLELEID=3410718;CLNDISDB=MedG...     KIF2A
# 99996  AF_EXAC=0.00001;ALLELEID=453441;CLNDISDB=.|MON...     PRKCD
# 99997  AF_EXAC=0.00577;AF_TGP=0.00040;ALLELEID=162985...     SIRT1
# 99998  ALLELEID=3824463;CLNDISDB=MedGen:C3661900;CLND...    ARID1A
# 99999  ALLELEID=3512783;CLNDISDB=.;CLNDN=PLXNA2-relat...    PLXNA2
#
#                        CLNSIG  \
# 0               Likely_benign
# 1               Likely_benign
# 2      Uncertain_significance
# 3               Likely_benign
# 4                      Benign
# ...                       ...
# 99995  Uncertain_significance
# 99996           Likely_benign
# 99997           Likely_benign
# 99998  Uncertain_significance
# 99999           Likely_benign
#
#                                                  DISEASE         RS  \
# 0             Cortical dysplasia-focal epilepsy syndrome  928114479
# 1                    DNAH9-related disorder|not provided  150023546
# 2      not provided|Pyogenic arthritis-pyoderma gangr...  756426938
# 3                                   Nance-Horan syndrome  777054929
# 4                                           not provided     922669
# ...                                                  ...        ...
# 99995                                      not specified  781206641
# 99996  PRKCD-related disorder|Autoimmune lymphoprolif...  782735766
# 99997                SIRT1-related disorder|not provided  550317521
# 99998                                       not provided       None
# 99999                            PLXNA2-related disorder       None
#
#                            CLNVC                      CLNHGVS  \
# 0      single_nucleotide_variant  NC_000007.14:g.146774401T>G
# 1      single_nucleotide_variant   NC_000017.11:g.11727893G>A
# 2      single_nucleotide_variant   NC_000015.10:g.77018465C>T
# 3      single_nucleotide_variant   NC_000023.11:g.17376123G>A
# 4      single_nucleotide_variant  NC_000015.10:g.100054211A>G
# ...                          ...                          ...
# 99995  single_nucleotide_variant   NC_000005.10:g.62357705G>T
# 99996  single_nucleotide_variant   NC_000003.12:g.53186256G>A
# 99997  single_nucleotide_variant   NC_000010.11:g.67885011C>A
# 99998  single_nucleotide_variant   NC_000001.11:g.26729868A>T
# 99999  single_nucleotide_variant  NC_000001.11:g.208043175A>G
#
#                                               CLNREVSTAT
# 0                    criteria provided, single submitter
# 1                    criteria provided, single submitter
# 2      criteria provided, multiple submitters, no con...
# 3                    criteria provided, single submitter
# 4      criteria provided, multiple submitters, no con...
# ...                                                  ...
# 99995                criteria provided, single submitter
# 99996  criteria provided, multiple submitters, no con...
# 99997  criteria provided, multiple submitters, no con...
# 99998                criteria provided, single submitter
# 99999                     no assertion criteria provided
#
# [100000 rows x 15 columns]

# %%
from clingen_handler import load_clingen_validity, get_clingen_classification
clingen_df = load_clingen_validity("Clingen-Gene-Disease-Summary-2025-07-01.csv")

# %%
 # Tüm merge edilecek sütunları aynı tipe dönüştür
clinvar_df["ClinGen_Validity"] = clinvar_df["GENE"].apply(lambda g: get_clingen_classification(g, clingen_df))

# %%
import requests

def get_pubmed_ids_from_clinvar(variation_id):
    url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/elink.fcgi"
    params = {
        "dbfrom": "clinvar",
        "db": "pubmed",
        "id": variation_id,
        "retmode": "json"
    }
    try:
        response = requests.get(url, params=params, timeout=10)
        response.raise_for_status()
        data = response.json()
        linksets = data.get("linksets", [])
        if not linksets or "linksetdbs" not in linksets[0]:
            return []
        pmids = []
        for db in linksets[0]["linksetdbs"]:
            if db["dbto"] == "pubmed":
                pmids.extend(db["links"])
        return pmids
    except:
        return []

def build_pubmed_links(pmid_list):
    return [f"https://pubmed.ncbi.nlm.nih.gov/{pmid}/" for pmid in pmid_list]

# %%
clin = clinvar_df[0:50]

# %%
import pandas as pd

# clin örnek veri yüklüyse devam:
for i, row in clin.head(50).iterrows():
    variation_id = row["ID"]
    if pd.isna(variation_id):
        print(f"{i}. satır → ID boş, atlandı.")
        continue

    pubmed_ids = get_pubmed_ids_from_clinvar(variation_id)
    pubmed_links = build_pubmed_links(pubmed_ids)

for i, row in merged_df.iterrows():
    st.write(f"🔍 {i+1}. varyant işleniyor: {row['CHROM']}:{row['POS']} {row['REF']}>{row['ALT']}")

    pubmed_ids = get_pubmed_ids_from_clinvar(row['ID']) if not pd.isna(row['ID']) else []
    pubmed_links = build_pubmed_links(pubmed_ids)
# Out:
# 🔍 0. satır - Variation ID: 1555617
# 🔗 PubMed IDs: ['28492532']
# 📚 PubMed Links: ['https://pubmed.ncbi.nlm.nih.gov/28492532/']
#
# 🔍 1. satır - Variation ID: 1455280
# 🔗 PubMed IDs: ['28492532']
# 📚 PubMed Links: ['https://pubmed.ncbi.nlm.nih.gov/28492532/']
#
# 🔍 2. satır - Variation ID: 451711
# 🔗 PubMed IDs: ['28492532']
# 📚 PubMed Links: ['https://pubmed.ncbi.nlm.nih.gov/28492532/']
#
# 🔍 3. satır - Variation ID: 2903273
# 🔗 PubMed IDs: []
# 📚 PubMed Links: Yok
#
# 🔍 4. satır - Variation ID: 1297461
# 🔗 PubMed IDs: ['25741868']
# 📚 PubMed Links: ['https://pubmed.ncbi.nlm.nih.gov/25741868/']
#
# 🔍 5. satır - Variation ID: 2962262
# 🔗 PubMed IDs: ['31536184', '28492532']
# 📚 PubMed Links: ['https://pubmed.ncbi.nlm.nih.gov/31536184/', 'https://pubmed.ncbi.nlm.nih.gov/28492532/']
#
# 🔍 6. satır - Variation ID: 2505191
# 🔗 PubMed IDs: ['25741868']
# 📚 PubMed Links: ['https://pubmed.ncbi.nlm.nih.gov/25741868/']
#
# 🔍 7. satır - Variation ID: 3594131
# 🔗 PubMed IDs: ['25741868', '20301643']
# 📚 PubMed Links: ['https://pubmed.ncbi.nlm.nih.gov/25741868/', 'https://pubmed.ncbi.nlm.nih.gov
# 🔗 PubMed IDs: ['28492532']
# 📚 PubMed Links: ['https://pubmed.ncbi.nlm.nih.gov/28492532/']
#
# 🔍 41. satır - Variation ID: 1758604
# 🔗 PubMed IDs: ['25394175']
# 📚 PubMed Links: ['https://pubmed.ncbi.nlm.nih.gov/25394175/']
#
# 🔍 42. satır - Variation ID: 195055
# 🔗 PubMed IDs: ['37053367', '28492532', '25741868']
# 📚 PubMed Links: ['https://pubmed.ncbi.nlm.nih.gov/37053367/', 'https://pubmed.ncbi.nlm.nih.gov/28492532/', 'https://pubmed.ncbi.nlm.nih.gov/25741868/']
#
# 🔍 43. satır - Variation ID: 1111923
# 🔗 PubMed IDs: ['28492532']
# 📚 PubMed Links: ['https://pubmed.ncbi.nlm.nih.gov/28492532/']
#
# 🔍 44. satır - Variation ID: 2367585
# 🔗 PubMed IDs: ['31022120', '25730230', '25626707', '24394680', '24121147', '24022298', '23881473', '23652378', '23619275', '23169492', '23037933', '22947299']
# 📚 PubMed Links: ['https://pubmed.ncbi.nlm.nih.gov/31022120/', 'https://pubmed.ncbi.nlm.nih.gov/25730230/', 'https://pubmed.ncbi.nlm.nih.gov/25626707/', 'https://pubmed.ncbi.nlm.nih.gov/24394680/', 'https://pubmed.ncbi.nlm.nih.gov/24121147/', 'https://pubmed.ncbi.nlm.nih.gov/24022298/', 'https://pubmed.ncbi.nlm.nih.gov/23881473/', 'https://pubmed.ncbi.nlm.nih.gov/23652378/', 'https://pubmed.ncbi.nlm.nih.gov/23619275/', 'https://pubmed.ncbi.nlm.nih.gov/23169492/', 'https://pubmed.ncbi.nlm.nih.gov/23037933/', 'https://pubmed.ncbi.nlm.nih.gov/22947299/']
#
# 🔍 45. satır - Variation ID: 3045913
# 🔗 PubMed IDs: []
# 📚 PubMed Links: Yok
#
# 🔍 46. satır - Variation ID: 3302267
# 🔗 PubMed IDs: []
# 📚 PubMed Links: Yok
#
# 🔍 47. satır - Variation ID: 3837322
# 🔗 PubMed IDs: []
# 📚 PubMed Links: Yok
#
# 🔍 48. satır - Variation ID: 2753299
# 🔗 PubMed IDs: ['28492532']
# 📚 PubMed Links: ['https://pubmed.ncbi.nlm.nih.gov/28492532/']
#
# 🔍 49. satır - Variation ID: 1987665
# 🔗 PubMed IDs: ['28492532', '20298421']
# 📚 PubMed Links: ['https://pubmed.ncbi.nlm.nih.gov/28492532/', 'https://pubmed.ncbi.nlm.nih.gov/20298421/']

# %%
import requests
def get_pubmed_ids_from_clinvar(variation_id):
    url = f"https://eutils.ncbi.nlm.nih.gov/entrez/eutils/elink.fcgi"
    params = {
        "dbfrom": "clinvar",
        "db": "pubmed",
        "id": variation_id,
        "retmode": "json"
    }
    response = requests.get(url, params=params)
    data = response.json()
    linksets = data.get("linksets", [])
    if not linksets or "linksetdbs" not in linksets[0]:
        return []
    pmids = []
    for db in linksets[0]["linksetdbs"]:
        if db["dbto"] == "pubmed":
            pmids.extend(db["links"])
    return pmids

# %%
print(get_pubmed_ids_from_clinvar(370969))
# Out:
# ['28492532', '27391550', '26908613', '25741868', '21447391', '20816175', '19299310']

# %%
def get_pubmed_links(pmid_list):
    return [f"https://pubmed.ncbi.nlm.nih.gov/{pmid}/" for pmid in pmid_list]

# Örnek kullanım:
pmids = get_pubmed_ids_from_clinvar(3385321)
links = get_pubmed_links(pmids)
print(links)
# Out:
# ['https://pubmed.ncbi.nlm.nih.gov/26666451/', 'https://pubmed.ncbi.nlm.nih.gov/25741868/', 'https://pubmed.ncbi.nlm.nih.gov/22234150/', 'https://pubmed.ncbi.nlm.nih.gov/20301590/']
